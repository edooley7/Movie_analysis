# %%
import pickle
import pandas as pd
from patsy import dmatrices
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
import numpy as np
from numpy import arange
import seaborn as sns
import matplotlib.pyplot as plt
import math
pd.options.mode.chained_assignment = None
# %matplotlib inline

# %%
with open("director_movie_data.pkl", 'r') as picklefile:
     all_movies = pickle.load(picklefile)

# %%
df = pd.DataFrame(all_movies)
df
# Out:
#                        director lifetime_films  lifetime_gross
# 0              Steven Spielberg             27      4155901520
# 1                   Michael Bay             11      2143487601
# 2                 Peter Jackson             12      2134703921
# 3               Robert Zemeckis             16      2039446164
# 4                 James Cameron              9      1974307733
# 5                    Ron Howard             21      1833703862
# 6             Christopher Nolan              9      1816484940
# 7                    Tim Burton             17      1752990124
# 8                  George Lucas              6      1743927001
# 9                Clint Eastwood             33      1690952072
# 10               Chris Columbus             14      1671507513
# 11                    Sam Raimi             14      1526694668
# 12               Gore Verbinski              9      1521303207
# 13                 Ridley Scott             21      1333302196
# 14                  Lee Unkrich              4      1331616576
# 15                  David Yates              4      1270958459
# 16              Roland Emmerich             10      1188885307
# 17               Andrew Adamson              6      1154738281
# 18             Francis Lawrence              5      1152882837
# 19               Richard Donner             16      1139106313
# 20                 Brett Ratner             10      1130771819
# 21                   Shawn Levy             11      1130331333
# 22                  Joss Whedon              4      1108509963
# 23                 Ivan Reitman             15      1099649856
# 24                 Dennis Dugan             14      1096734782
# 25                   Tony Scott             16      1092613610
# 26                    Jay Roach              8      1087562875
# 27             Barry Sonnenfeld             10      1058597570
# 28            Steven Soderbergh             26      1039340590
# 29                John Lasseter              5      1035982355
# ..                          ...            ...             ...
# 797                 Kevin Bacon              2           97384
# 798                   Tim Allen              1           88335
# 799                    Don Hahn              1           80741
# 800             Anthony Hopkins              2           78046
# 801                 John August              1           63165
# 802              Melisa Wallack              1           62597
# 803             William H. Macy              1           58293
# 804                 Peter Tolan              1           57297
# 805               Goro Miyazaki              1           48461
# 806                Ryan Gosling              1           45431
# 807             Matthew Lillard              1           41457
# 808              John Krasinski              1           33745
# 809                Nicolas Cage              1           30005
# 810           Geoffrey Fletcher              1           17186
# 811             William Monahan              1           16075
# 812                Lonzo Nzekwe              1           15790
# 813          Billy Bob Thornton              1           14836
# 814                Stewart Wade              2           13879
# 815                Mark Ruffalo              1           13826
# 816            Michele Mulroney              1           13514
# 817             Kieran Mulroney              1           13514
# 818          Dustin Lance Black              1           12728
# 819         Ryan Piers Williams              1           11777
# 820             Ernie Barbarash              1           11774
# 821                Nia Vardalos              1           11004
# 822               Courteney Cox              1           10970
# 823                 Eran Creevy              1            9747
# 824  Thomas Lennon & Ben Garant              1            8785
# 825                Greta Gerwig              1            5430
# 826               Famke Janssen              1            4975
#
# [827 rows x 3 columns]
